# %% [markdown]
# <a href="https://colab.research.google.com/github/KhinMyoMyatKyaw1996/MMDT_T-PY101_Batch03/blob/main/KhinMyoMyatKyaw/Ex01_Intro_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import numpy as np
import pandas as pd

import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD: 13
# 13 usd is equivalent to 10.66 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
fahrenheit = input("Enter the temperature in Fahrenheit: ")
celsius = (int(fahrenheit) - 32) * 5 / 9

print("{} Fahrenheit is equivalent to {} Celsius".format(fahrenheit, celsius))
# Out:
# Enter the temperature in Fahrenheit: 25
# 25 Fahrenheit is equivalent to -3.888888888888889 Celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple_qty = int(input("Enter the quantity of apples: "))
apple_price = float(input("Enter the price of one apple: "))
apple_total = apple_qty * apple_price

orange_qty = int(input("Enter the quantity of oranges: "))
orange_price = float(input("Enter the price of one orange: "))
orange_total = orange_qty * orange_price

mango_qty = int(input("Enter the quantity of mangoes: "))
mango_price = float(input("Enter the price of one mango: "))
mango_total = mango_qty * mango_price

total_cost = apple_total + orange_total + mango_total

print("The total cost for the customer is:", total_cost)
# Out:
# Enter the quantity of apples: 5
# Enter the price of one apple: 250
# Enter the quantity of oranges: 3
# Enter the price of one orange: 300
# Enter the quantity of mangoes: 10
# Enter the price of one mango: 800
# The total cost for the customer is: 10150.0

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
customer_name = input("Enter your name: ")
print("Hello " + customer_name)
# Out:
# Enter your name: Khin
# Hello Khin

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint

x = randint(1, 50)
y = randint(2, 5)

result = x ** y

print("Random number x (1 to 50):", x)
print("Random number y (2 to 5):", y)
print("x^y =", result)
# Out:
# Random number x (1 to 50): 27
# Random number y (2 to 5): 3
# x^y = 19683

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint

x = randint(1, 10)
name = input("Enter your name: ")

print("Random number:", x)

for i in range(x):
    print(name)
# Out:
# Enter your name: Khin
# Random number: 9
# Khin
# Khin
# Khin
# Khin
# Khin
# Khin
# Khin
# Khin
# Khin

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = float(input("Enter value of x: "))
y = float(input("Enter value of y: "))

result = abs(x - y) / (x + y)

print("Result =", result)
# Out:
# Enter value of x: 3
# Enter value of y: 5
# Result = 0.25

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
total_seconds = int(input("Enter the number of seconds: "))

minutes = total_seconds // 60
seconds = total_seconds % 60

print("{} seconds is {} minutes and {} seconds".format(
    total_seconds, minutes, seconds
))
# Out:
# Enter the number of seconds: 200
# 200 seconds is 3 minutes and 20 seconds

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math

num = float(input("Enter a number: "))

sine_value = math.sin(num)
cosine_value = math.cos(num)
tangent_value = math.tan(num)

print("Sine:", sine_value)
print("Cosine:", cosine_value)
print("Tangent:", tangent_value)
# Out:
# Enter a number: 25
# Sine: -0.13235175009777303
# Cosine: 0.9912028118634736
# Tangent: -0.13352640702153587
